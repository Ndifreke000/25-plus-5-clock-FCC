# %% [markdown]
# <a href="https://colab.research.google.com/github/Ndifreke000/25-plus-5-clock-FCC/blob/main/1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 1.7 MB/s eta 0:00:00
# ...

# %%
import openai
import csv

openai.api_key = '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'

def generate_tweet(prompt):
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=50
    )
    return response.choices[0].text.strip()

def generate_dataset():
    dataset = []
    for _ in range(1000):
        user_type = "student" if _ < 500 else "lecturer"
        prompt = f"As a {user_type} during the ASUU strike, I feel: "
        tweet = generate_tweet(prompt)
        dataset.append([user_type, tweet])
    return dataset

# Generate the dataset
dataset = generate_dataset()

# Write the dataset to a CSV file
with open('asuu_tweets_dataset.csv', 'w', newline='', encoding='utf-8') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['user_type', 'tweet'])
    csvwriter.writerows(dataset)

print("ASUU Tweets dataset generated.")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-12-65a03da322fa> in <cell line: 24>()
#      22
#      23 # Generate the dataset
# ---> 24 dataset = generate_dataset()
#      25
#      26 # Write the dataset to a CSV file
#
# <ipython-input-12-65a03da322fa> in generate_dataset()
#      17         user_type = "student" if _ < 500 else "lecturer"
#      18         prompt = f"As a {user_type} during the ASUU strike, I feel: "
# ---> 19         tweet = generate_tweet(prompt)
#      20         dataset.append([user_type, tweet])
#      21     return dataset
#
# <ipython-input-12-65a03da322fa> in generate_tweet(prompt)
#       5
#       6 def generate_tweet(prompt):
# ----> 7     response = openai.Completion.create(
#       8         engine="text-davinci-003",
#       9         prompt=prompt,
#
# ...

# %%
pip install nltk

# %%
import csv
import nltk
import random

nltk.download('words')  # Download the list of English words

# Load the list of English words
words = nltk.corpus.words.words()

def generate_pseudo_tweet(user_type):
    num_words = random.randint(5, 15)  # Random number of words per tweet
    pseudo_tweet = ' '.join(random.choice(words) for _ in range(num_words))
    return pseudo_tweet

def generate_dataset():
    dataset = []
    for _ in range(1000):
        user_type = "student" if _ < 500 else "lecturer"
        pseudo_tweet = generate_pseudo_tweet(user_type)
        dataset.append([user_type, pseudo_tweet])
    return dataset

# Generate the dataset
dataset = generate_dataset()

# Write the dataset to a CSV file
with open('asuu_tweets_dataset_nltk.csv', 'w', newline='', encoding='utf-8') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['user_type', 'tweet'])
    csvwriter.writerows(dataset)

print("ASUU Tweets dataset generated using NLTK.")
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# ASUU Tweets dataset generated using NLTK.

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('asuu_tweets_dataset_nltk.csv')

# Display the first few rows
print(df)
# Out:
#     user_type                                              tweet
# 0     student  acropetal imaginative dasypaedic Tokay footsta...
# 1     student  Potiguara sphacelial overland noontide mannife...
# 2     student  portalless inamorate quadrivious inwardly invo...
# 3     student  pseudomembranous inrunning tulchan cylinder ca...
# 4     student  pseudoval Thalassinidea plateiasmus thermopene...
# 5     student  reinvest Mithriac childbirth retouchment malfe...
# 6     student  activin unexpended anhemolytic saturation unpr...
# 7     student  flirtingly piperaceous fungin recognizant wate...
# 8     student  chafe cookery unlaid longfin poignancy winning...
# 9     student  competitive hypothesize cark splenepatitis pol...
# 10    student       nibbed fipple cessantly aerographer Orotinan
# 11    student  supratropical rejectage pyrrole Clayoquot exce...
# 12    student  chabuk idola snagrel logotype egipto Centraxon...
# ...

# %%
import csv
import random
import nltk
from nltk.corpus import words
from faker import Faker

nltk.download('words')

fake = Faker()
word_list = words.words()

def generate_pseudo_tweet():
    num_words = random.randint(5, 15)
    pseudo_tweet = ' '.join(random.choice(word_list) for _ in range(num_words))
    return pseudo_tweet

def generate_dataset():
    dataset = []
    for i in range(1, 1001):
        user_type = "student" if i <= 500 else "lecturer"
        tweet = generate_pseudo_tweet()
        dataset.append([i, user_type, tweet])
    return dataset

# Generate the dataset
dataset = generate_dataset()

# Write the dataset to a CSV file
with open('asuu_tweets_dataset_nltk.csv', 'w', newline='', encoding='utf-8') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['tweet_id', 'user_type', 'tweet'])
    csvwriter.writerows(dataset)

print("NLTK-based ASUU Tweets dataset generated.")
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# NLTK-based ASUU Tweets dataset generated.

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('asuu_tweets_dataset_nltk.csv')

# Display the first few rows
print(df)
# Out:
#      tweet_id user_type                                              tweet
# 0           1   student  onyx dicodeine alegar nonventilation peatman g...
# 1           2   student  blithering celibatory coot Drawcansir obscured...
# 2           3   student  afterfuture sluggardness tonishly Inocarpus so...
# 3           4   student  Pectinibranchiata obviate recommendability wid...
# 4           5   student  resensation loin aesthetic priestling unscrupu...
# 5           6   student  tysonite pseudoisomeric language glassful rese...
# 6           7   student  superbity ambassador theosophistic Star Ceyx o...
# 7           8   student  unfretting nonhydrolyzable leafwork honorworth...
# 8           9   student  fastidiously latrant outshrill porcellanid com...
# 9          10   student  wabster diphtheroid shagginess Tagalize mislab...
# 10         11   student  sphenolith scyphi siamang Horonite Trigla guar...
# ...

# %%
pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 42.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 22.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 89.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 65.8 MB/s eta 0:00:00
# ...

# %%
import csv
import random
import torch
from transformers import BertTokenizer, BertForSequenceClassification

# Load pre-trained BERT model and tokenizer for sentiment analysis
model_name = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForSequenceClassification.from_pretrained(model_name, num_labels=2)  # 2 labels: positive and negative

def generate_dataset():
    dataset = []
    for i in range(1, 1001):
        user_type = "student" if i <= 500 else "lecturer"
        tweet = generate_tweet()  # Replace with your own tweet generation function
        dataset.append([i, user_type, tweet])
    return dataset

# Replace this function with your own tweet generation logic
def generate_tweet():
    # Generate a pseudo tweet
    return "This ASUU strike is affecting my studies. #ASUU #Education"

# Generate the dataset
dataset = generate_dataset()


# Write the dataset to a CSV file
with open('asuu_tweets_sentiment_dataset.csv', 'w', newline='', encoding='utf-8') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['tweet_id', 'user_type', 'tweet', 'sentiment'])
    csvwriter.writerows(dataset)

print("BERT-based ASUU Tweets Sentiment dataset generated.")
# Out:
# ...
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERT-based ASUU Tweets Sentiment dataset generated.

# %%
# !pip install sentencepiece

# %%
# Install SentencePiece manually
# !pip install sentencepiece

# Now you can proceed with the rest of your code
import csv
import random
import torch
from transformers import T5ForConditionalGeneration, T5Tokenizer

# Load pre-trained T5 model and tokenizer
model_name = 't5-small'
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)



def generate_tweet(prompt):
    input_ids = tokenizer.encode(prompt, return_tensors='pt')
    with torch.no_grad():
        output = model.generate(input_ids)
    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
    return generated_text

def generate_dataset():
    dataset = []
    for i in range(1, 1001):
        user_type = "student" if i <= 500 else "lecturer"
        prompt = f"As a {user_type} during the ASUU strike, I feel: "
        tweet = generate_tweet(prompt)
        dataset.append([i, user_type, tweet])
    return dataset

# Generate the dataset
dataset = generate_dataset()

# Write the dataset to a CSV file
with open('asuu_tweets_t5_dataset.csv', 'w', newline='', encoding='utf-8') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['tweet_id', 'user_type', 'tweet'])
    csvwriter.writerows(dataset)

print("T5-based ASUU Tweets dataset generated.")
# Out:
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-26-41344985638a> in <cell line: 12>()
#      10 # Load pre-trained T5 model and tokenizer
#      11 model_name = 't5-small'
# ---> 12 tokenizer = T5Tokenizer.from_pretrained(model_name)
#      13 model = T5ForConditionalGeneration.from_pretrained(model_name)
#      14
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in __getattribute__(cls, key)
#    1037         if key.startswith("_") and key != "_from_config":
#    1038             return super().__getattribute__(key)
# -> 1039         requires_backends(cls, cls._backends)
#    1040
#    1041
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in requires_backends(obj, backends)
#    1025     failed = [msg.format(name) for available, msg in checks if not available()]
#    1026     if failed:
# ...

# %%
import random

def generate_tweet(is_student):
    if is_student:
        student_words = ["lectures", "classes", "exams", "degree", "future"]
        sentiment = ["frustrated", "angry", "disappointed"]
    else:
        lecturer_words = ["salary", "funding", "research", "students", "government"]
        sentiment = ["stressed", "worried", "hopeless"]

    words = student_words if is_student else lecturer_words
    sentiment = sentiment[random.randint(0, len(sentiment) - 1)]

    return "I'm so {} because of the ASUU strike! #ASUU #Nigeria".format(sentiment)

def main():
    tweets = []
    for i in range(1000):
        is_student = random.randint(0, 1)
        tweet = generate_tweet(is_student)
        tweets.append(tweet)

    with open("asuu_tweets.csv", "w") as f:
        for tweet in tweets:
            f.write(tweet + "\n")

if __name__ == "__main__":
    main()

# %%
pip install pytube
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.3 MB/s eta 0:00:00
# ...

# %%
from pytube import YouTube
import csv

# Replace 'video_url' with the URL of the YouTube video
video_url = 'https://www.youtube.com/watch?v=_wOzKYFP1Oc'

# Load the YouTube video
video = YouTube(video_url)

# Fetch the comments from the video
comments = []
for comment in video.comments:
    comments.append(comment.text)

# Specify the CSV file name
csv_filename = 'youtube_comments.csv'

# Write the comments to a CSV file
with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['Comment'])
    for comment in comments:
        csvwriter.writerow([comment])

print(f'Comments saved to {csv_filename}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-c6bafd6222df> in <cell line: 12>()
#      10 # Fetch the comments from the video
#      11 comments = []
# ---> 12 for comment in video.comments:
#      13     comments.append(comment.text)
#      14
#
# AttributeError: 'YouTube' object has no attribute 'comments'

# %%
pip install youtube-comment-scraper
# Out:
# ERROR: Could not find a version that satisfies the requirement youtube-comment-scraper (from versions: none)
# ERROR: No matching distribution found for youtube-comment-scraper

# %%
import csv
from youtube_comment_scraper import *

# Replace 'VIDEO_URL' with the URL of the YouTube video
video_url = 'VIDEO_URL'

# Initialize the YouTubeCommentScraper
scraper = YouTubeCommentScraper()

# Fetch video comments
comments = scraper.get_comments(video_url)

# Save comments to CSV file
csv_filename = 'youtube_comments.csv'
with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['Comment'])
    for comment in comments:
        csvwriter.writerow([comment])

print(f'Comments saved to {csv_filename}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-9d08b0fa7a5c> in <cell line: 2>()
#       1 import csv
# ----> 2 from youtube_comment_scraper import *
#       3
#       4 # Replace 'VIDEO_URL' with the URL of the YouTube video
#       5 video_url = 'VIDEO_URL'
#
# ModuleNotFoundError: No module named 'youtube_comment_scraper'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import pandas as pd
import googleapiclient.discovery
from furl import furl
import re

VIDEO_URL = 'https://youtu.be/_wOzKYFP1Oc' # Your YouTube Video URL
MAX_COMMENTS = 10 * 100 # maximum 10 unit quota with 100 comments per request

API_SERVICE_NAME = "youtube"
API_VERSION = "v3"
API_KEY = 'AIzaSyDj9DyKs0m5JMHXf-HyDSIRenJOrzgpV4o'

def get_video_id(video_url):
    if len(video_url):
        f = furl(video_url)
        if len(f.args) and 'v' in list(f.args.keys()):
            return f.args['v']
    return None

def get_youtube_client():
    return googleapiclient.discovery.build(
        API_SERVICE_NAME, API_VERSION, developerKey = API_KEY)

def get_video_info(video_id):
    request = get_youtube_client().videos().list(
        part="snippet,contentDetails,statistics",
        id=video_id
    )
    return request.execute()

def get_video_title(video_info):
    return video_info['items'][0]['snippet']['title']

def get_channel_title(video_info):
    return video_info['items'][0]['snippet']['channelTitle']

def get_comments_by_video(video_id, nextPageToken=None):
    request = get_youtube_client().commentThreads().list(
        part="snippet,replies",
        videoId=video_id,
        maxResults=100,
        pageToken=nextPageToken
    )
    return request.execute()

def get_all_comments(video_id, max_comments):
    comments_list = []
    nextPageToken = None

    while True:
        comments = get_comments_by_video(video_id, nextPageToken)
        comments_list.extend(comments['items'])

        if len(comments_list) >= max_comments or 'nextPageToken' not in comments:
            break

        nextPageToken = comments['nextPageToken']
    return comments_list

def get_replies(comments):
    replies = []
    for c in comments:
        if 'replies' in c:
            replies.extend(c['replies']['comments'])
    return replies

def main():
    video_id = get_video_id((VIDEO_URL))
    video_info = get_video_info(video_id)

    video_title = get_video_title(video_info)
    channel_title = get_channel_title(video_info)

    clean_title = re.sub(r'[^\w\s]+', '', video_title)
    filename = f'{channel_title} - {clean_title[:30]} - {video_id}'

    # Top Level Comments
    comments = get_all_comments(video_id, MAX_COMMENTS)
    df_comments = pd.json_normalize(comments)
    df_comments.drop(columns=['kind', 'etag', 'id', 'snippet.videoId'], inplace=True)
    df_comments.columns = df_comments.columns.str.removeprefix('snippet.topLevelComment.').str.removeprefix('snippet.').str.removesuffix('.value').str.removesuffix('.comments')
    df_comments.to_csv('comments-' + filename + '.csv', index=False)

    # Replies
    replies = get_replies(comments)
    df_replies = pd.json_normalize(replies)
    df_replies.head()
    df_replies.columns = df_replies.columns.str.removeprefix('snippet.').str.removesuffix('.value')
    df_replies.to_csv('replies-' + filename + '.csv', index=False)

    print(f'Comments = {len(df_comments)}')
    print(f'Replies = {len(df_replies)}')
    print(f'Total = {len(df_comments) + len(df_replies)}')

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-0e56ff64c6dd> in <cell line: 3>()
#       1 import pandas as pd
#       2 import googleapiclient.discovery
# ----> 3 from furl import furl
#       4 import re
#       5
#
# ModuleNotFoundError: No module named 'furl'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pandas openpyxl

# %%
import pandas as pd

file_path = '/content/sales_data.csv'
data = pd.read_csv(file_path)
print(data.head())

sales = pd.read_csv(
    '/content/sales_data.csv',
    parse_dates=['Date'])
sales.head()

sales['Customer_Age'].mean()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
import pandas as pd
import numpy as np

g7_pop = pd.Series([35.467, 63.951, 80.940, 60.665, 127.061, 64.511, 318.523])

pd.Series(
    [35.467, 63.951, 80.94, 60.665, 127.061, 64.511, 318.523],
    index=['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
       'United States'],
    name='G7 Population in millions')

df
df.iloc[-1]
# Out:
# Population       318.523
# GDP             17348075
# Surface Area     9525067
# HDI                0.915
# Continent        America
# Name: 6, dtype: object

# %%
df = pd.DataFrame({
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
}, columns=['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'])
df
df.iloc[-1]
# Out:
# Population       318.523
# GDP             17348075
# Surface Area     9525067
# HDI                0.915
# Continent        America
# Name: 6, dtype: object

# %%
import pandas as pd
import numpy as np

print(pd.__version__)

# pd.Series()
J = ['A','B','C']
print(J, type(J))

Y = pd.Series(J)
print(J, type(J))

J = pd.Series(['A','B','C'])

J.name = 'My letters'
J.values
# Out:
# 1.5.3
# ['A', 'B', 'C'] <class 'list'>
# ['A', 'B', 'C'] <class 'list'>
# array(['A', 'B', 'C'], dtype=object)

# %%
import numpy as np
import pandas as pd
ambassadors = pd.Series([
    'France',
    'United Kingdom',
    'United Kingdom',
    'Italy',
    'Germany',
    'Germany',
    'Germany',
], index=[
    'Gérard Araud',
    'Kim Darroch',
    'Peter Westmacott',
    'Armando Varricchio',
    'Peter Wittig',
    'Peter Ammon',
    'Klaus Scharioth '
])

ambassadors
ambassadors.duplicated()
# Out:
# Gérard Araud          False
# Kim Darroch           False
# Peter Westmacott       True
# Armando Varricchio    False
# Peter Wittig          False
# Peter Ammon            True
# Klaus Scharioth        True
# dtype: bool

# %%
# !pip install -q sklearn
# Out:
#   Preparing metadata (setup.py) ... done
# ...

# %%
pip install snscrape

# %%
import tweepy

# Set up your Twitter API credentials
consumer_key = 'YOUR_CONSUMER_KEY'
consumer_secret = 'YOUR_CONSUMER_SECRET'
access_token = 'YOUR_ACCESS_TOKEN'
access_token_secret = 'YOUR_ACCESS_TOKEN_SECRET'

# Authenticate with the Twitter API
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# Create the API object
api = tweepy.API(auth)

# Define the date range
start_date = '2022-03-01'
end_date = '2022-09-30'

# Define the hashtags to search for
hashtags = ['#ASUU', '#ASUUStrike']

# Iterate over the hashtags and retrieve tweets
for hashtag in hashtags:
    query = f'{hashtag} since:{start_date} until:{end_date}'
    tweets = tweepy.Cursor(api.search_tweets, q=query, tweet_mode='extended').items()

    # Iterate over the tweets and print them
    for tweet in tweets:
        print(tweet.full_text)
# Out:
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# <ipython-input-7-bb0d004419a3> in <cell line: 24>()
#      27
#      28     # Iterate over the tweets and print them
# ---> 29     for tweet in tweets:
#      30         print(tweet.full_text)
#      31
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
# ...

# %%
pip install tweepy

# %%
import tweepy

# Set your Twitter API credentials
consumer_key = 'JXRN8j3ZB22PiNKXBOcw2fPxU'
consumer_secret = 'RYHxUa1Mu4fUA8b7xttWHhDcmxfXdjDKdZOIMDc0SrC5cm9N1l'
access_token = '981585424056569856-5vNYHLfGVLoKIBVEEMk8a8c4BWeSmzK'
access_token_secret = 'KKvnSm9GwpoDTg8LVy71PeNlRROtrK2uUoDA8rcXlrsuy'

# Authenticate with Twitter API
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# Define hashtags and time range
hashtags = ['#ASUU', '#ASUU_STRIKE', '#ASUUStrike']
start_date = '2022-05-01'
end_date = '2022-09-30'

# Number of tweets to retrieve
num_tweets = 500

# Retrieve and process tweets
for hashtag in hashtags:
    query = f'{hashtag} since:{start_date} until:{end_date}'
    tweets = tweepy.Cursor(api.search_tweets, q=query, lang='en').items(num_tweets)

    for tweet in tweets:
        print(tweet.created_at, tweet.user.screen_name, tweet.text)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-1-57f94cbc3e73> in <cell line: 23>()
#      25     tweets = tweepy.Cursor(api.search_tweets, q=query, lang='en').items(num_tweets)
#      26
# ---> 27     for tweet in tweets:
#      28         print(tweet.created_at, tweet.user.screen_name, tweet.text)
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
# ...

# %%
import tweepy
import pandas as pd

consumer_key='JXRN8j3ZB22PiNKXBOcw2fPxU'

consumer_secret= 'RYHxUa1Mu4fUA8b7xttWHhDcmxfXdjDKdZOIMDc0SrC5cm9N1l'

access_token= '981585424056569856-5vNYHLfGVLoKIBVEEMk8a8c4BWeSmzK'

access_token_secret='KKvnSm9GwpoDTg8LVy71PeNlRROtrK2uUoDA8rcXlrsuy'


#Pass in our twitter API authentication key
auth = tweepy.OAuth1UserHandler(
    consumer_key, consumer_secret,
    access_token, access_token_secret
)

#Instantiate the tweepy API
api = tweepy.API(auth, wait_on_rate_limit=True)


# Define hashtags and time range
hashtags = ['#ASUU', '#ASUU_STRIKE', '#ASUUStrike']
start_date = '2022-05-01'
end_date = '2022-09-30'

# Number of tweets to retrieve
num_tweets = 500

try:
    #The number of tweets we want to retrieved from the search
    tweets = api.search_tweets(q=search_query, lang="en", count=no_of_tweets, tweet_mode ='extended')

    #Pulling Some attributes from the tweet
    attributes_container = [[tweet.user.name, tweet.created_at, tweet.favorite_count, tweet.source, tweet.full_text] for tweet in tweets]

    #Creation of column list to rename the columns in the dataframe
    columns = ["User", "Date Created", "Number of Likes", "Source of Tweet", "Tweet"]

    #Creation of Dataframe
    tweets_df = pd.DataFrame(attributes_container, columns=columns)
except BaseException as e:
    print('Status Failed On,',str(e))
# Out:
# Status Failed On, name 'search_query' is not defined

# %%
pip install Faker
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.4 MB/s eta 0:00:00
# ...

# %%
import csv
import random
from faker import Faker
from datetime import datetime, timedelta

fake = Faker()

# Generate 1000 pseudo entries
data = []
for i in range(1, 1001):
    username = fake.user_name()
    date_time = (datetime.now() - timedelta(days=random.randint(1, 365), hours=random.randint(1, 24))).strftime('%Y-%m-%d %H:%M:%S')
    tweet_text = fake.sentence() + f" #{fake.word()} #{fake.word()}"
    data.append([i, username, date_time, tweet_text])

# Write to CSV file
with open('pseudo_tweets.csv', 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['tweet_id', 'username', 'date_time', 'tweet_text'])
    csvwriter.writerows(data)

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('pseudo_tweets.csv')

# Display all rows
pd.set_option('display.max_rows', None)  # Show all rows
print(df)
# Out:
#      tweet_id             username            date_time  \
# 0           1           wisephilip  2022-11-26 14:59:18
# 1           2            owilliams  2022-12-03 05:59:18
# 2           3             qgoodman  2022-11-25 19:59:18
# 3           4          paynestacey  2022-11-13 10:59:18
# 4           5          randallhale  2023-03-28 08:59:18
# 5           6               fsmith  2022-11-29 15:59:18
# 6           7              ududley  2022-09-26 22:59:18
# 7           8             hschultz  2023-08-12 01:59:18
# 8           9             andrew94  2022-10-17 19:59:18
# 9          10       deannagalloway  2022-11-08 07:59:18
# 10         11               carl94  2022-10-17 06:59:18
# 11         12     sandrarichardson  2022-12-19 07:59:18
# 12         13             joseph61  2023-05-03 05:59:18
# 13         14          jamesguzman  2023-02-26 04:59:18
# 14         15      margaretshepard  2023-04-22 05:59:18
# 15         16           keithdaisy  2022-10-26 13:59:18
# ...

# %%
import csv
import random
from faker import Faker
from datetime import datetime, timedelta

fake = Faker()

# Generate 1000 pseudo entries
data = []
for i in range(1, 1001):
    username = fake.user_name()
    date_time = (datetime.now() - timedelta(days=random.randint(1, 365), hours=random.randint(1, 24))).strftime('%Y-%m-%d %H:%M:%S')
    complaint = fake.random_element([
        "I can't believe we're dealing with another ASUU strike! This is getting frustrating! 😡 #ASUU #EducationMatters",
        f"This ongoing ASUU strike is affecting our study plans. When will it end? 😫📚 #ASUU",
        f"Every year, it's the same story with the ASUU strike. It's time for a change! 🤬 #ASUU #StudentsDeserveBetter",
        f"I'm going to show the world that I'm not going to be defeated by the ASUU strike.",
        f"I'm starting to lose hope that the ASUU strike will ever end.",
        f"The ASUU strike is a disaster for Nigerian students. We're losing valuable time and opportunities.",
        f"I'm so angry with the government for not doing more to resolve the ASUU strike. This is a national emergency!",
        f"I'm not sure what I'm going to do with my life if the ASUU strike doesn't end soon.",

        # ... Add more complaint-like statements
    ])
    data.append([i, username, date_time, complaint])

# Write to CSV file
with open('pseudo_asuu_tweets.csv', 'w', newline='', encoding='utf-8') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['tweet_id', 'username', 'date_time', 'tweet_text'])
    csvwriter.writerows(data)

print("Pseudo ASUU Tweets dataset generated.")
# Out:
# Pseudo ASUU Tweets dataset generated.

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('pseudo_asuu_tweets.csv')

# Display the first few rows
#print(df.head())

# To display all rows, you can use:
print(df)
# Out:
#      tweet_id             username            date_time  \
# 0           1           tonyagreen  2022-11-17 14:06:24
# 1           2             vandrews  2022-11-29 23:06:24
# 2           3           nicholas50  2022-10-27 01:06:24
# 3           4              brian08  2023-05-27 01:06:24
# 4           5           samantha28  2023-07-11 15:06:24
# 5           6              vburton  2023-08-16 02:06:24
# 6           7           nicolebell  2022-09-14 14:06:24
# 7           8           hojeremiah  2023-01-02 18:06:24
# 8           9       huffmanmichael  2023-03-22 15:06:24
# 9          10             amanda17  2023-07-02 11:06:24
# 10         11             rodney39  2022-12-19 15:06:24
# 11         12               emma65  2023-02-28 06:06:24
# 12         13       angelaandersen  2023-05-24 07:06:24
# 13         14              xgentry  2023-04-27 12:06:24
# 14         15          jamesgaines  2023-03-12 22:06:24
# 15         16                 xcox  2023-07-18 00:06:24
# ...
